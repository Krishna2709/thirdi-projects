# %%
import logging
import pandas as pd
import time

from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

logging.basicConfig(level=logging.INFO)

# %%
edge_options = Options()
user_agent = "Edge/122.0.2365.92"
edge_options.add_argument(f'user-agent={user_agent}')
url = "https://www.facebook.com/marketplace/104146386288393/propertyforsale/?sortBy=creation_time_descend"
driver = webdriver.Edge(options=edge_options)
driver.get(url)
time.sleep(3)

for _ in range(10):
    driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.PAGE_DOWN)
    time.sleep(1)
    
html_content = driver.page_source
driver.quit()

soup = BeautifulSoup(html_content, 'html.parser')

# List of tags to remove
unwanted_tags = ['script', 'style', 'button', 'input', 'img', 'video', 'head', 'svg']

for tag in unwanted_tags:
    for unwanted_tag in soup.find_all(tag):
        unwanted_tag.decompose()  # Remove the tag from the soup

# %%
section = soup.find("div", class_="x8gbvx8 x78zum5 x1q0g3np x1a02dak x1nhvcw1 x1rdy4ex xcud41i x4vbgl9 x139jcc6")
listings = section.find_all("div", class_="x9f619 x78zum5 x1r8uery xdt5ytf x1iyjqo2 xs83m0k x1e558r4 x150jy0e x1iorvi4 xjkvuk6 xnpuxes x291uyu x1uepa24")

# %%
# Initialize lists to store the extracted data
data = []

# Extract information for each listing
for listing in listings:

    link_element = listing.find('a', class_='x1i10hfl')
    link_href = link_element['href'] if link_element else None
    link_href = f"https://www.facebook.com{link_href}" if link_href else None

    # Extracting the price
    price_element = listing.find('span', class_='x193iq5w')
    price = price_element.get_text() if price_element else None

    # Extracting the property details
    details_element = listing.find('span', style=lambda value: value and '-webkit-line-clamp: 2' in value)
    details = details_element.get_text() if details_element else None

    # Extracting the address
    address_element = listing.find('span', class_='x1nxh6w3')
    address = address_element.get_text() if address_element else None

    data.append({
        "Price": price,
        "Details": details,
        "Address": address,
        "Link": link_href
    })

df = pd.DataFrame(data)

# %%
df
# Out:
#          Price                             Details               Address  \
# 0      $15,000                1 Bed 1 Bath - House         Worcester, MA
# 1     $629,900                4 Beds 2 Baths House         Tyngsboro, MA
# 2     $950,000            4 Beds 2.5 Baths - House         Hampstead, NH
# 3         $750               2 Beds 1 Bath - House           Roxbury, MA
# 4         $300               3 Drawer Night Stand          Pawtucket, RI
# 5         $620                       Drawer Chest          Pawtucket, RI
# 6     $689,900            4 Beds 2.5 Baths - House  East Bridgewater, MA
# 7     $489,900          3 Beds 2 Baths - Townhouse           Whitman, MA
# 8      $15,000                1 Bed 1 Bath - House         Worcester, MA
# 9   $1,379,000              4 Beds 3.5 Baths House             Acton, MA
# 10    $950,000            3 Beds 2 Baths Apartment      South Boston, MA
# 11    $479,000            2 Beds 3 Baths Townhouse         Tewksbury, MA
# 12    $159,000               2 Beds 1 Bath - House        Middleboro, MA
# 13    $829,900                2 Beds 2 Baths House        Swampscott, MA
# 14      $1,000            1 Bed 1 Bath - Apartment            Revere, MA
# 15    $724,900              2 Beds 2 Baths - House            Rowley, MA
# 16    $149,900              2 Beds 2 Baths - House           Taunton, MA
# 17        $850  1 habitación 1 baño - Departamento              Lynn, MA
# 18      $1,160           3 Beds 1 Bath - Apartment           Allston, MA
# 19      $2,750              1 Bed 1 Bath Apartment       East Boston, MA
# 20    $120,000         99 Beds 2 Baths - Apartment         Cambridge, MA
# 21    $899,999            3 Beds 1.5 Baths - House         Lynnfield, MA
# 22    $850,000              3 Beds 3 Baths - House       East Boston, MA
# 23    $675,000              4 Beds 2 Baths - House            Canton, MA
# 24    $360,000                3 Beds 2 Baths House        Providence, RI
# 25    $890,000              4 Beds 2 Baths - House          Westford, MA
# 26    $996,000         1 Bed 1.5 Baths - Apartment            Boston, MA
# 27        $150                          Dishwasher            Malden, MA
# 28         $50         3 quartos 1 banheiro – Casa         Billerica, MA
# 29      $5,200             5 Beds 1 Bath Apartment        Somerville, MA
# 30      $5,800            5 Beds 2 Baths Apartment         Brookline, MA
# 31    $629,000               3 Beds 1 Bath - House              Lynn, MA
# 32    $449,900                4 Beds 2 Baths House        Woonsocket, RI
# 33    $549,900              3 Beds 1.5 Baths House             Salem, NH
# 34    $735,000          3 Beds 3 Baths - Townhouse       East Boston, MA
# 35    $375,000               4 Beds 1 Bath - House        Providence, RI
# 36    $695,000                3 Beds 2 Baths House        Marshfield, MA
# 37        $930            2 Beds 2 Baths Apartment           Allston, MA
# 38    $385,000          3 Beds 1.5 Baths Townhouse         Lunenburg, MA
# 39    $869,000                4 Beds 3 Baths House       Londonderry, NH
# 40    $464,900                3 Beds 2 Baths House            Nashua, NH
# 41    $459,900               2 Beds 1 Bath - House         Leicester, MA
# 42  $2,100,000            5 Beds 5.5 Baths - House        Burlington, MA
# 43          $1          1 quarto 1 banheiro – Casa        Framingham, MA
# 44        None                                None                  None
# 45        None                                None                  None
# 46        None                                None                  None
# 47        None                                None                  None
# 48        None                                None                  None
# 49        None                                None                  None
# 50        None                                None                  None
# 51        None                                None                  None
#
#                                                  Link
# 0   https://www.facebook.com/marketplace/item/9618...
# 1   https://www.facebook.com/marketplace/item/2607...
# 2   https://www.facebook.com/marketplace/item/7921...
# 3   https://www.facebook.com/marketplace/item/1370...
# 4   https://www.facebook.com/marketplace/item/7195...
# 5   https://www.facebook.com/marketplace/item/9418...
# 6   https://www.facebook.com/marketplace/item/7501...
# 7   https://www.facebook.com/marketplace/item/3768...
# 8   https://www.facebook.com/marketplace/item/1899...
# 9   https://www.facebook.com/marketplace/item/3501...
# 10  https://www.facebook.com/marketplace/item/2738...
# 11  https://www.facebook.com/marketplace/item/1363...
# 12  https://www.facebook.com/marketplace/item/8048...
# 13  https://www.facebook.com/marketplace/item/6166...
# 14  https://www.facebook.com/marketplace/item/7178...
# 15  https://www.facebook.com/marketplace/item/1134...
# 16  https://www.facebook.com/marketplace/item/2501...
# 17  https://www.facebook.com/marketplace/item/7695...
# 18  https://www.facebook.com/marketplace/item/3770...
# 19  https://www.facebook.com/marketplace/item/8207...
# 20  https://www.facebook.com/marketplace/item/2907...
# 21  https://www.facebook.com/marketplace/item/7569...
# 22  https://www.facebook.com/marketplace/item/3855...
# 23  https://www.facebook.com/marketplace/item/3738...
# 24  https://www.facebook.com/marketplace/item/1172...
# 25  https://www.facebook.com/marketplace/item/2908...
# 26  https://www.facebook.com/marketplace/item/2855...
# 27  https://www.facebook.com/marketplace/item/1107...
# 28  https://www.facebook.com/marketplace/item/4536...
# 29  https://www.facebook.com/marketplace/item/9321...
# 30  https://www.facebook.com/marketplace/item/3590...
# 31  https://www.facebook.com/marketplace/item/7704...
# 32  https://www.facebook.com/marketplace/item/7858...
# 33  https://www.facebook.com/marketplace/item/1613...
# 34  https://www.facebook.com/marketplace/item/3719...
# 35  https://www.facebook.com/marketplace/item/2517...
# 36  https://www.facebook.com/marketplace/item/1129...
# 37  https://www.facebook.com/marketplace/item/1790...
# 38  https://www.facebook.com/marketplace/item/7834...
# 39  https://www.facebook.com/marketplace/item/9513...
# 40  https://www.facebook.com/marketplace/item/9300...
# 41  https://www.facebook.com/marketplace/item/1572...
# 42  https://www.facebook.com/marketplace/item/1527...
# 43  https://www.facebook.com/marketplace/item/1491...
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None

# %%
# 1. Remove entries with price < $100,000
# 2. Remove entries where Link is None
# - We can remove entries based out of MA
df_filtered = df[df['Link'].notna()]
df_filtered = df_filtered[df_filtered['Price'].replace('[\$,]', '', regex=True).astype(float) >= 100000]
df_filtered
# Out:
#          Price                      Details               Address  \
# 1     $629,900         4 Beds 2 Baths House         Tyngsboro, MA
# 2     $950,000     4 Beds 2.5 Baths - House         Hampstead, NH
# 6     $689,900     4 Beds 2.5 Baths - House  East Bridgewater, MA
# 7     $489,900   3 Beds 2 Baths - Townhouse           Whitman, MA
# 9   $1,379,000       4 Beds 3.5 Baths House             Acton, MA
# 10    $950,000     3 Beds 2 Baths Apartment      South Boston, MA
# 11    $479,000     2 Beds 3 Baths Townhouse         Tewksbury, MA
# 12    $159,000        2 Beds 1 Bath - House        Middleboro, MA
# 13    $829,900         2 Beds 2 Baths House        Swampscott, MA
# 15    $724,900       2 Beds 2 Baths - House            Rowley, MA
# 16    $149,900       2 Beds 2 Baths - House           Taunton, MA
# 20    $120,000  99 Beds 2 Baths - Apartment         Cambridge, MA
# 21    $899,999     3 Beds 1.5 Baths - House         Lynnfield, MA
# 22    $850,000       3 Beds 3 Baths - House       East Boston, MA
# 23    $675,000       4 Beds 2 Baths - House            Canton, MA
# 24    $360,000         3 Beds 2 Baths House        Providence, RI
# 25    $890,000       4 Beds 2 Baths - House          Westford, MA
# 26    $996,000  1 Bed 1.5 Baths - Apartment            Boston, MA
# 31    $629,000        3 Beds 1 Bath - House              Lynn, MA
# 32    $449,900         4 Beds 2 Baths House        Woonsocket, RI
# 33    $549,900       3 Beds 1.5 Baths House             Salem, NH
# 34    $735,000   3 Beds 3 Baths - Townhouse       East Boston, MA
# 35    $375,000        4 Beds 1 Bath - House        Providence, RI
# 36    $695,000         3 Beds 2 Baths House        Marshfield, MA
# 38    $385,000   3 Beds 1.5 Baths Townhouse         Lunenburg, MA
# 39    $869,000         4 Beds 3 Baths House       Londonderry, NH
# 40    $464,900         3 Beds 2 Baths House            Nashua, NH
# 41    $459,900        2 Beds 1 Bath - House         Leicester, MA
# 42  $2,100,000     5 Beds 5.5 Baths - House        Burlington, MA
#
#                                                  Link
# 1   https://www.facebook.com/marketplace/item/2607...
# 2   https://www.facebook.com/marketplace/item/7921...
# 6   https://www.facebook.com/marketplace/item/7501...
# 7   https://www.facebook.com/marketplace/item/3768...
# 9   https://www.facebook.com/marketplace/item/3501...
# 10  https://www.facebook.com/marketplace/item/2738...
# 11  https://www.facebook.com/marketplace/item/1363...
# 12  https://www.facebook.com/marketplace/item/8048...
# 13  https://www.facebook.com/marketplace/item/6166...
# 15  https://www.facebook.com/marketplace/item/1134...
# 16  https://www.facebook.com/marketplace/item/2501...
# 20  https://www.facebook.com/marketplace/item/2907...
# 21  https://www.facebook.com/marketplace/item/7569...
# 22  https://www.facebook.com/marketplace/item/3855...
# 23  https://www.facebook.com/marketplace/item/3738...
# 24  https://www.facebook.com/marketplace/item/1172...
# 25  https://www.facebook.com/marketplace/item/2908...
# 26  https://www.facebook.com/marketplace/item/2855...
# 31  https://www.facebook.com/marketplace/item/7704...
# 32  https://www.facebook.com/marketplace/item/7858...
# 33  https://www.facebook.com/marketplace/item/1613...
# 34  https://www.facebook.com/marketplace/item/3719...
# 35  https://www.facebook.com/marketplace/item/2517...
# 36  https://www.facebook.com/marketplace/item/1129...
# 38  https://www.facebook.com/marketplace/item/7834...
# 39  https://www.facebook.com/marketplace/item/9513...
# 40  https://www.facebook.com/marketplace/item/9300...
# 41  https://www.facebook.com/marketplace/item/1572...
# 42  https://www.facebook.com/marketplace/item/1527...

# %%
# Save the DataFrame to a CSV file
csv_file_path = 'fb_listings.csv'
df.to_csv(csv_file_path, index=False)
print(f'Saved extracted information to {csv_file_path}')

# Alternatively, to save it as an Excel file, you can do:
excel_file_path = 'fb_listings.xlsx'
df.to_excel(excel_file_path, index=False)
print(f'Saved extracted information to {excel_file_path}')
# Out:
# Saved extracted information to fb_listings.csv
# Saved extracted information to fb_listings.xlsx
